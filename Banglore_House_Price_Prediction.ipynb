# %%
import pandas as pd

# %%
df = pd.read_csv("/content/bangalore house price prediction OHE-data.csv")

# %%
df.head()
# Out:
#    bath  balcony  ...  location_Mahadevpura  location_Tumkur Road
# 0   3.0      2.0  ...                     0                     0
# 1   3.0      3.0  ...                     0                     0
# 2   3.0      2.0  ...                     0                     0
# 3   2.0      2.0  ...                     0                     0
# 4   2.0      2.0  ...                     0                     0
#
# [5 rows x 108 columns]

# %%
df.shape
# Out:
# (7120, 108)

# %%
df.tail()
# Out:
#       bath  balcony  ...  location_Mahadevpura  location_Tumkur Road
# 7115   3.0      2.0  ...                     0                     0
# 7116   3.0      1.0  ...                     0                     0
# 7117   2.0      1.0  ...                     0                     0
# 7118   2.0      1.0  ...                     0                     0
# 7119   2.0      1.0  ...                     0                     0
#
# [5 rows x 108 columns]

# %% [markdown]
# SPLIT DATA

# %%
x = df.drop('price', axis = 1)
y = df['price']

print('shape of X = ', x.shape)
print('shape of Y = ', y.shape)
# Out:
# shape of X =  (7120, 107)
# shape of Y =  (7120,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.1, random_state = 51)
print('Shape of X_train = ', X_train.shape)
print('Shape of Y_train = ', Y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of Y_test = ', Y_test.shape)
# Out:
# Shape of X_train =  (6408, 107)
# Shape of Y_train =  (6408,)
# Shape of X_test =  (712, 107)
# Shape of Y_test =  (712,)

# %% [markdown]
# FEATURE SCALING

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train = sc.transform(X_train)
X_test= sc.transform(X_test)

# %% [markdown]
# LINEAR REGRESSION -ML MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_  #values of coefficients(beta)
# Out:
# array([-4.17189136e-01, -4.06421450e-01,  7.95194617e+01, -1.35178456e+01,
#         6.50460951e+01,  1.09185448e+00, -5.26372652e-01, -3.16881839e+00,
#        -2.15066923e+00, -3.92983150e+00, -2.59786884e+00,  5.91155724e-01,
#        -1.04484070e+00,  2.02740419e+00,  2.59857236e-01, -1.47008090e+00,
#        -1.97447591e-01,  2.50487276e+00, -1.66448618e+00,  2.40037452e+00,
#        -3.08840030e+00, -1.57541165e+00, -9.76395640e-01, -1.25952062e-01,
#         1.31570227e+00,  1.63361545e+00, -5.02846018e+00, -1.07607435e+00,
#        -5.78055210e-01,  1.83001677e+00, -5.36825757e-01, -5.74415341e-02,
#         6.95796482e-01, -1.56649543e+00,  7.26964286e-02, -1.51529061e+00,
#         4.67228474e-01,  8.97990979e-01,  3.35168373e+00,  1.37526284e-01,
#         4.29282524e-01,  3.76098323e-01, -2.96759148e-01,  1.14098538e+00,
#        -1.65214123e+00, -3.53342315e+00,  5.29432065e-02,  8.41804399e-03,
# ...

# %%
lr.intercept_ #value of interecept learned by the model
# Out:
# 96.45062109862673

# %% [markdown]
# Predict the value of home and test

# %%
X_test[0, :]
# Out:
# array([ 0.69785363,  0.00858983,  0.25974587,  0.64141367, -0.47607315,
#        -1.73061043,  2.10926044, -0.25595664,  0.51056129, -0.18270663,
#        -0.16408253, -0.14835622, -0.13031282, -0.12844245, -0.12718125,
#        -0.12332528, -0.12590824, -0.12201455, -0.12069044, -0.11385244,
#        -0.10955604, -0.11028316, -0.10955604, -0.11028316, -0.0938942 ,
#        -0.08687445, -0.08687445, -0.091323  , -0.08595799, -0.08867981,
#        -0.08219304, -0.08219304, -0.0812253 , -0.07825222, -0.07620739,
#        -0.07825222, -0.07620739, -0.07723641, -0.07194769, -0.0730354 ,
#        -0.07084363, -0.07825222, -0.0730354 , -0.07410748, -0.0751646 ,
#        -0.0751646 , -0.0685833 , -0.07194769, -0.07084363, -0.07410748,
#        -0.06624738, -0.0685833 , -0.07084363, -0.06972245, -0.06382756,
#        -0.06742527, -0.06382756, -0.06624738, -0.06624738, -0.06258317,
#        -0.06382756, -0.06504853, -0.06382756, -0.06382756, -0.06504853,
# ...

# %%
lr.predict([X_test[0, :]])
# Out:
# array([75.82920093])

# %%
lr.predict(X_test)
# Out:
# array([ 7.58292009e+01,  1.27713756e+01,  1.16215442e+02,  8.26386508e+01,
#         2.21923093e+01,  3.78152086e+01,  4.31962815e+01,  8.83476119e+01,
#         1.14729508e+02,  6.23189957e+01,  1.08828341e+02,  3.08672451e+02,
#         3.29310710e+02,  3.02108958e+02,  2.05081374e+02,  5.15665585e+01,
#         1.06104935e+02,  9.56748472e+01,  1.74645354e+02,  5.58114326e+01,
#         7.01925401e+01,  3.39072098e+01,  3.11653297e+01,  5.94902493e+01,
#         2.17852527e+02,  4.15725344e+02, -1.20590245e+01,  9.61728695e+01,
#         1.69758463e+02,  1.77436923e+02,  4.97780043e+01,  4.07331891e+01,
#         3.06679380e+02,  3.08462224e+02,  1.06622837e+02,  5.09731730e+01,
#         6.33827216e+01,  1.09351561e+02,  4.22857018e+00,  1.01336107e+02,
#         5.92146495e+01,  1.30867333e+01,  8.27669422e+01,  7.68844712e+01,
#         7.76570698e+01,  5.43436776e+01,  8.62060442e+01,  9.92068263e+01,
# ...

# %%
Y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 4305    120.00
# 555     140.00
# 7085     36.85
# 1570     44.80
# 4410     75.00
# Name: price, Length: 712, dtype: float64

# %%
lr.score(X_test, Y_test)
# Out:
# 0.9021315840297928
